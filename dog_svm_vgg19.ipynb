# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg19
from tensorflow_vgg import utils

data_dir = 'dogImages/'
contents = os.listdir(data_dir)
classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:   
    vgg = vgg19.Vgg19()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                
                # Image batch to pass to VGG network
                
                images = np.concatenate(batch)
                
                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu7, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /home/wangyao/Desktop/Transfer_Learning/tensorflow_vgg/vgg19.npy
# npy file loaded
# build model started
# build model finished: 0s
# Starting 056.Dachshund images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 100.Lowchen images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 001.Affenpinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 065.Entlebucher_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 092.Keeshond images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 064.English_toy_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 015.Basset_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 92 images processed
# Starting 085.Irish_red_and_white_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 46 images processed
# Starting 060.Dogue_de_bordeaux images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 75 images processed
# Starting 039.Bull_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 87 images processed
# Starting 026.Black_russian_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 021.Belgian_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 130.Welsh_springer_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 016.Beagle images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 74 images processed
# Starting 094.Komondor images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 105.Neapolitan_mastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 39 images processed
# Starting 040.Bulldog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 037.Brittany images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 034.Boxer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 082.Havanese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 76 images processed
# Starting 133.Yorkshire_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 052.Clumber_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 61 images processed
# Starting 126.Saint_bernard images
# 10 images processed
# 20 images processed
# 30 images processed
# 37 images processed
# Starting 032.Boston_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed
# Starting 003.Airedale_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 65 images processed
# Starting 048.Chihuahua images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 68 images processed
# Starting 086.Irish_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 089.Irish_wolfhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 074.Giant_schnauzer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 076.Golden_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 120.Pharaoh_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 073.German_wirehaired_pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 52 images processed
# Starting 127.Silky_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 095.Kuvasz images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 61 images processed
# Starting 042.Cairn_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 081.Greyhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# Starting 066.Field_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 41 images processed
# Starting 069.French_bulldog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 64 images processed
# Starting 041.Bullmastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 86 images processed
# Starting 028.Bluetick_coonhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 091.Japanese_chin images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 024.Bichon_frise images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 77 images processed
# Starting 102.Manchester_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 36 images processed
# Starting 109.Norwegian_elkhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 56 images processed
# Starting 108.Norwegian_buhund images
# 10 images processed
# 20 images processed
# 30 images processed
# 33 images processed
# Starting 054.Collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 124.Poodle images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 111.Norwich_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 121.Plott images
# 10 images processed
# 20 images processed
# 30 images processed
# 35 images processed
# Starting 078.Great_dane images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# Starting 055.Curly-coated_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 008.American_staffordshire_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 088.Irish_water_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 64 images processed
# Starting 030.Border_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 65 images processed
# Starting 007.American_foxhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 025.Black_and_tan_coonhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 46 images processed
# Starting 004.Akita images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 117.Pekingese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 132.Xoloitzcuintli images
# 10 images processed
# 20 images processed
# 30 images processed
# 33 images processed
# Starting 096.Labrador_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 54 images processed
# Starting 035.Boykin_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 093.Kerry_blue_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 002.Afghan_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 73 images processed
# Starting 114.Otterhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 027.Bloodhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 046.Cavalier_king_charles_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 84 images processed
# Starting 033.Bouvier_des_flandres images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 56 images processed
# Starting 038.Brussels_griffon images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 031.Borzoi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# Starting 122.Pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# Starting 014.Basenji images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 86 images processed
# Starting 047.Chesapeake_bay_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 67 images processed
# Starting 006.American_eskimo_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 050.Chinese_shar-pei images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 005.Alaskan_malamute images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 96 images processed
# Starting 062.English_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 083.Ibizan_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 101.Maltese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 084.Icelandic_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 123.Pomeranian images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 061.English_cocker_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 76 images processed
# Starting 058.Dandie_dinmont_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 044.Cane_corso images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 059.Doberman_pinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 113.Old_english_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 022.Belgian_tervuren images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 070.German_pinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 118.Pembroke_welsh_corgi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 097.Lakeland_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 080.Greater_swiss_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 57 images processed
# Starting 077.Gordon_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 54 images processed
# Starting 013.Australian_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 009.American_water_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 075.Glen_of_imaal_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 119.Petit_basset_griffon_vendeen images
# 10 images processed
# 20 images processed
# 30 images processed
# 39 images processed
# Starting 057.Dalmatian images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 89 images processed
# Starting 043.Canaan_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 017.Bearded_collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 77 images processed
# Starting 053.Cocker_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 068.Flat-coated_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 129.Tibetan_mastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 010.Anatolian_shepherd_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 012.Australian_shepherd images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 83 images processed
# Starting 019.Bedlington_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 128.Smooth_fox_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 131.Wirehaired_pointing_griffon images
# 10 images processed
# 20 images processed
# 30 images processed
# 37 images processed
# Starting 110.Norwegian_lundehund images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 41 images processed
# Starting 104.Miniature_schnauzer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 011.Australian_cattle_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 83 images processed
# Starting 087.Irish_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 029.Border_collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 93 images processed
# Starting 051.Chow_chow images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 115.Papillon images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 103.Mastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 72 images processed
# Starting 018.Beauceron images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 020.Belgian_malinois images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 063.English_springer_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 036.Briard images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed
# Starting 098.Leonberger images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 57 images processed
# Starting .ipynb_checkpoints images
# Starting 072.German_shorthaired_pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 106.Newfoundland images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 049.Chinese_crested images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 079.Great_pyrenees images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 74 images processed
# Starting 116.Parson_russell_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 090.Italian_greyhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 73 images processed
# Starting 107.Norfolk_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 099.Lhasa_apso images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 045.Cardigan_welsh_corgi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 112.Nova_scotia_duck_tolling_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 67 images processed
# Starting 067.Finnish_spitz images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 071.German_shepherd_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 125.Portuguese_water_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 023.Bernese_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed

# %%
# write codes to file
with open('codes_vgg19', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels_vgg19', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %%
# read codes and labels from file
import csv

with open('labels_vgg19') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader]).squeeze()
with open('codes_vgg19') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
# One-hot encode labels
from sklearn import preprocessing

lb = preprocessing.LabelBinarizer()
lb.fit(labels)
labels_vecs = lb.transform(labels)

# %%
# Split the codes and labels into training, validation, and test sets
from sklearn.model_selection import StratifiedShuffleSplit

ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
train_idx, val_idx = next(ss.split(codes, labels))

half_val_len = int(len(val_idx)/2)
val_idx, test_idx = val_idx[:half_val_len], val_idx[half_val_len:]

train_x, train_y = codes[train_idx], labels_vecs[train_idx]
val_x, val_y = codes[val_idx], labels_vecs[val_idx]
test_x, test_y = codes[test_idx], labels_vecs[test_idx]

# %%
print("Train shapes (x, y):", train_x.shape, train_y.shape)
print("Validation shapes (x, y):", val_x.shape, val_y.shape)
print("Test shapes (x, y):", test_x.shape, test_y.shape)
# Out:
# Train shapes (x, y): (6680, 4096) (6680, 133)
# Validation shapes (x, y): (835, 4096) (835, 133)
# Test shapes (x, y): (836, 4096) (836, 133)

# %%
inputs_ = tf.placeholder(tf.float32, shape=[None, codes.shape[1]])
labels_ = tf.placeholder(tf.int64, shape=[None, labels_vecs.shape[1]])

fc = tf.contrib.layers.fully_connected(inputs_, 256)
    
logits = tf.contrib.layers.fully_connected(fc, labels_vecs.shape[1], activation_fn=None)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=labels_, logits=logits)
cost = tf.reduce_mean(cross_entropy)

optimizer = tf.train.AdamOptimizer().minimize(cost)

predicted = tf.nn.softmax(logits)
correct_pred = tf.equal(tf.argmax(predicted, 1), tf.argmax(labels_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
def get_batches(x, y, n_batches=10):
    """ Return a generator that yields batches from arrays x and y. """
    batch_size = len(x)//n_batches
    
    for ii in range(0, n_batches*batch_size, batch_size):
        if ii != (n_batches-1)*batch_size:
            X, Y = x[ii: ii+batch_size], y[ii: ii+batch_size] 
        else:
            X, Y = x[ii:], y[ii:]
        yield X, Y

# %%
epochs = 10
iteration = 0
saver = tf.train.Saver()

with tf.Session() as sess:
    
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for x, y in get_batches(train_x, train_y):
            feed = {inputs_: x,
                    labels_: y}
            loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            print("Epoch: {}/{}".format(e+1, epochs),
                  "Iteration: {}".format(iteration),
                  "Training loss: {:.5f}".format(loss))
            iteration += 1
            
            if iteration % 5 == 0:
                feed = {inputs_: val_x,
                        labels_: val_y}
                val_acc = sess.run(accuracy, feed_dict=feed)
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Validation Acc: {:.4f}".format(val_acc))
    saver.save(sess, "checkpoints/dogs.ckpt")
# Out:
# Epoch: 1/10 Iteration: 0 Training loss: 6.16899
# Epoch: 1/10 Iteration: 1 Training loss: 4.21672
# Epoch: 1/10 Iteration: 2 Training loss: 3.32184
# Epoch: 1/10 Iteration: 3 Training loss: 2.61073
# Epoch: 1/10 Iteration: 4 Training loss: 2.12746
# Epoch: 0/10 Iteration: 5 Validation Acc: 0.6108
# Epoch: 1/10 Iteration: 5 Training loss: 1.75416
# Epoch: 1/10 Iteration: 6 Training loss: 1.37686
# Epoch: 1/10 Iteration: 7 Training loss: 1.35410
# Epoch: 1/10 Iteration: 8 Training loss: 0.97576
# Epoch: 1/10 Iteration: 9 Training loss: 0.92735
# Epoch: 0/10 Iteration: 10 Validation Acc: 0.7820
# Epoch: 2/10 Iteration: 10 Training loss: 0.56131
# Epoch: 2/10 Iteration: 11 Training loss: 0.56839
# Epoch: 2/10 Iteration: 12 Training loss: 0.52722
# Epoch: 2/10 Iteration: 13 Training loss: 0.52087
# Epoch: 2/10 Iteration: 14 Training loss: 0.48926
# Epoch: 1/10 Iteration: 15 Validation Acc: 0.7988
# Epoch: 2/10 Iteration: 15 Training loss: 0.47356
# Epoch: 2/10 Iteration: 16 Training loss: 0.42094
# Epoch: 2/10 Iteration: 17 Training loss: 0.48483
# Epoch: 2/10 Iteration: 18 Training loss: 0.38188
# Epoch: 2/10 Iteration: 19 Training loss: 0.37450
# Epoch: 1/10 Iteration: 20 Validation Acc: 0.8383
# Epoch: 3/10 Iteration: 20 Training loss: 0.29340
# Epoch: 3/10 Iteration: 21 Training loss: 0.25855
# Epoch: 3/10 Iteration: 22 Training loss: 0.29157
# Epoch: 3/10 Iteration: 23 Training loss: 0.28907
# Epoch: 3/10 Iteration: 24 Training loss: 0.26956
# Epoch: 2/10 Iteration: 25 Validation Acc: 0.8431
# Epoch: 3/10 Iteration: 25 Training loss: 0.24308
# Epoch: 3/10 Iteration: 26 Training loss: 0.18661
# Epoch: 3/10 Iteration: 27 Training loss: 0.24978
# Epoch: 3/10 Iteration: 28 Training loss: 0.25033
# Epoch: 3/10 Iteration: 29 Training loss: 0.23871
# Epoch: 2/10 Iteration: 30 Validation Acc: 0.8611
# Epoch: 4/10 Iteration: 30 Training loss: 0.15623
# Epoch: 4/10 Iteration: 31 Training loss: 0.14874
# Epoch: 4/10 Iteration: 32 Training loss: 0.15603
# Epoch: 4/10 Iteration: 33 Training loss: 0.16239
# Epoch: 4/10 Iteration: 34 Training loss: 0.15461
# Epoch: 3/10 Iteration: 35 Validation Acc: 0.8635
# Epoch: 4/10 Iteration: 35 Training loss: 0.15240
# Epoch: 4/10 Iteration: 36 Training loss: 0.12922
# Epoch: 4/10 Iteration: 37 Training loss: 0.12611
# Epoch: 4/10 Iteration: 38 Training loss: 0.13991
# Epoch: 4/10 Iteration: 39 Training loss: 0.10614
# Epoch: 3/10 Iteration: 40 Validation Acc: 0.8719
# Epoch: 5/10 Iteration: 40 Training loss: 0.08716
# Epoch: 5/10 Iteration: 41 Training loss: 0.07995
# Epoch: 5/10 Iteration: 42 Training loss: 0.09721
# Epoch: 5/10 Iteration: 43 Training loss: 0.08774
# Epoch: 5/10 Iteration: 44 Training loss: 0.08725
# Epoch: 4/10 Iteration: 45 Validation Acc: 0.8707
# Epoch: 5/10 Iteration: 45 Training loss: 0.07763
# Epoch: 5/10 Iteration: 46 Training loss: 0.08354
# Epoch: 5/10 Iteration: 47 Training loss: 0.07312
# Epoch: 5/10 Iteration: 48 Training loss: 0.07476
# Epoch: 5/10 Iteration: 49 Training loss: 0.07439
# Epoch: 4/10 Iteration: 50 Validation Acc: 0.8743
# Epoch: 6/10 Iteration: 50 Training loss: 0.05091
# Epoch: 6/10 Iteration: 51 Training loss: 0.05266
# Epoch: 6/10 Iteration: 52 Training loss: 0.05909
# Epoch: 6/10 Iteration: 53 Training loss: 0.05528
# Epoch: 6/10 Iteration: 54 Training loss: 0.05709
# Epoch: 5/10 Iteration: 55 Validation Acc: 0.8802
# Epoch: 6/10 Iteration: 55 Training loss: 0.05728
# Epoch: 6/10 Iteration: 56 Training loss: 0.06658
# Epoch: 6/10 Iteration: 57 Training loss: 0.03916
# Epoch: 6/10 Iteration: 58 Training loss: 0.05054
# Epoch: 6/10 Iteration: 59 Training loss: 0.04562
# Epoch: 5/10 Iteration: 60 Validation Acc: 0.8778
# Epoch: 7/10 Iteration: 60 Training loss: 0.04223
# Epoch: 7/10 Iteration: 61 Training loss: 0.04357
# Epoch: 7/10 Iteration: 62 Training loss: 0.04881
# Epoch: 7/10 Iteration: 63 Training loss: 0.04532
# Epoch: 7/10 Iteration: 64 Training loss: 0.03211
# Epoch: 6/10 Iteration: 65 Validation Acc: 0.8802
# Epoch: 7/10 Iteration: 65 Training loss: 0.03207
# Epoch: 7/10 Iteration: 66 Training loss: 0.03896
# Epoch: 7/10 Iteration: 67 Training loss: 0.03024
# Epoch: 7/10 Iteration: 68 Training loss: 0.04435
# Epoch: 7/10 Iteration: 69 Training loss: 0.05537
# Epoch: 6/10 Iteration: 70 Validation Acc: 0.8826
# Epoch: 8/10 Iteration: 70 Training loss: 0.03238
# Epoch: 8/10 Iteration: 71 Training loss: 0.02205
# Epoch: 8/10 Iteration: 72 Training loss: 0.03175
# Epoch: 8/10 Iteration: 73 Training loss: 0.04546
# Epoch: 8/10 Iteration: 74 Training loss: 0.02890
# Epoch: 7/10 Iteration: 75 Validation Acc: 0.8754
# Epoch: 8/10 Iteration: 75 Training loss: 0.03468
# Epoch: 8/10 Iteration: 76 Training loss: 0.02666
# Epoch: 8/10 Iteration: 77 Training loss: 0.02506
# Epoch: 8/10 Iteration: 78 Training loss: 0.02370
# Epoch: 8/10 Iteration: 79 Training loss: 0.06529
# Epoch: 7/10 Iteration: 80 Validation Acc: 0.8802
# Epoch: 9/10 Iteration: 80 Training loss: 0.06778
# Epoch: 9/10 Iteration: 81 Training loss: 0.02546
# Epoch: 9/10 Iteration: 82 Training loss: 0.01865
# Epoch: 9/10 Iteration: 83 Training loss: 0.02175
# Epoch: 9/10 Iteration: 84 Training loss: 0.01873
# Epoch: 8/10 Iteration: 85 Validation Acc: 0.8814
# Epoch: 9/10 Iteration: 85 Training loss: 0.03869
# Epoch: 9/10 Iteration: 86 Training loss: 0.02556
# Epoch: 9/10 Iteration: 87 Training loss: 0.04121
# Epoch: 9/10 Iteration: 88 Training loss: 0.02400
# Epoch: 9/10 Iteration: 89 Training loss: 0.01878
# Epoch: 8/10 Iteration: 90 Validation Acc: 0.8838
# Epoch: 10/10 Iteration: 90 Training loss: 0.02607
# Epoch: 10/10 Iteration: 91 Training loss: 0.01563
# Epoch: 10/10 Iteration: 92 Training loss: 0.03023
# Epoch: 10/10 Iteration: 93 Training loss: 0.02653
# Epoch: 10/10 Iteration: 94 Training loss: 0.02428
# Epoch: 9/10 Iteration: 95 Validation Acc: 0.8850
# Epoch: 10/10 Iteration: 95 Training loss: 0.01577
# Epoch: 10/10 Iteration: 96 Training loss: 0.02422
# Epoch: 10/10 Iteration: 97 Training loss: 0.01639
# Epoch: 10/10 Iteration: 98 Training loss: 0.02285
# Epoch: 10/10 Iteration: 99 Training loss: 0.03770
# Epoch: 9/10 Iteration: 100 Validation Acc: 0.8707

# %%
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    feed = {inputs_: test_x,
            labels_: test_y}
    test_acc = sess.run(accuracy, feed_dict=feed)
    print("Test accuracy: {:.4f}".format(test_acc))
# Out:
# Test accuracy: 0.8505

# %%
import sklearn
from sklearn import svm
from sklearn import cross_validation, grid_search
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC
from sklearn.externals import joblib
 
def train_svm_classifer(codes, labels):
    # save 20% of data for performance evaluation
    X_train, X_test, y_train, y_test = cross_validation.train_test_split(codes, labels, train_size=0.8, test_size=0.1)
    print("Train shapes (x, y):", X_train.shape, y_train.shape)
    print("Test shapes (x, y):", X_test.shape, y_test.shape)
    
    clf = svm.SVC(C=1, kernel='linear', probability=True)
    clf.fit(X_train, y_train)
        
    score = clf.score(X_test,y_test)
    print("Test accuracy:", score)

# %%
train_svm_classifer(codes,labels)
# Out:
# Train shapes (x, y): (6680, 4096) (6680,)
# Test shapes (x, y): (836, 4096) (836,)
# Test accuracy: 0.873205741627
