# %%
import os

import numpy as np
import tensorflow as tf

from tensorflow_vgg import vgg16
from tensorflow_vgg import utils

data_dir = 'dogImages/'
contents = os.listdir(data_dir)
classes = [each for each in contents if os.path.isdir(data_dir + each)]

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

batch_size = 10
codes_list = []
labels = []
batch = []

codes = None

with tf.Session() as sess:   
    vgg = vgg16.Vgg16()
    input_ = tf.placeholder(tf.float32, [None, 224, 224, 3])
    with tf.name_scope("content_vgg"):
        vgg.build(input_)

    for each in classes:
        print("Starting {} images".format(each))
        class_path = data_dir + each
        files = os.listdir(class_path)
        for ii, file in enumerate(files, 1):
            # Add images to the current batch
            # utils.load_image crops the input images for us, from the center
            img = utils.load_image(os.path.join(class_path, file))
            batch.append(img.reshape((1, 224, 224, 3)))
            labels.append(each)
            
            # Running the batch through the network to get the codes
            if ii % batch_size == 0 or ii == len(files):
                
                # Image batch to pass to VGG network
                
                images = np.concatenate(batch)
                
                feed_dict = {input_: images}
                codes_batch = sess.run(vgg.relu7, feed_dict=feed_dict)
                
                # Here I'm building an array of the codes
                if codes is None:
                    codes = codes_batch
                else:
                    codes = np.concatenate((codes, codes_batch))
                
                # Reset to start building the next batch
                batch = []
                print('{} images processed'.format(ii))
# Out:
# /home/wangyao/Desktop/Transfer_Learning/tensorflow_vgg/vgg16.npy
# npy file loaded
# build model started
# build model finished: 0s
# Starting 056.Dachshund images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 100.Lowchen images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 001.Affenpinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 065.Entlebucher_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 092.Keeshond images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 064.English_toy_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 015.Basset_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 92 images processed
# Starting 085.Irish_red_and_white_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 46 images processed
# Starting 060.Dogue_de_bordeaux images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 75 images processed
# Starting 039.Bull_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 87 images processed
# Starting 026.Black_russian_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 021.Belgian_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 130.Welsh_springer_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 016.Beagle images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 74 images processed
# Starting 094.Komondor images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 105.Neapolitan_mastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 39 images processed
# Starting 040.Bulldog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 037.Brittany images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 034.Boxer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 082.Havanese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 76 images processed
# Starting 133.Yorkshire_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 052.Clumber_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 61 images processed
# Starting 126.Saint_bernard images
# 10 images processed
# 20 images processed
# 30 images processed
# 37 images processed
# Starting 032.Boston_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed
# Starting 003.Airedale_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 65 images processed
# Starting 048.Chihuahua images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 68 images processed
# Starting 086.Irish_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 089.Irish_wolfhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 074.Giant_schnauzer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 076.Golden_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 120.Pharaoh_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 073.German_wirehaired_pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 52 images processed
# Starting 127.Silky_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 51 images processed
# Starting 095.Kuvasz images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 61 images processed
# Starting 042.Cairn_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 081.Greyhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# Starting 066.Field_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 41 images processed
# Starting 069.French_bulldog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 64 images processed
# Starting 041.Bullmastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 86 images processed
# Starting 028.Bluetick_coonhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 091.Japanese_chin images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 024.Bichon_frise images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 77 images processed
# Starting 102.Manchester_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 36 images processed
# Starting 109.Norwegian_elkhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 56 images processed
# Starting 108.Norwegian_buhund images
# 10 images processed
# 20 images processed
# 30 images processed
# 33 images processed
# Starting 054.Collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 124.Poodle images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 111.Norwich_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 121.Plott images
# 10 images processed
# 20 images processed
# 30 images processed
# 35 images processed
# Starting 078.Great_dane images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# Starting 055.Curly-coated_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 008.American_staffordshire_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 088.Irish_water_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 64 images processed
# Starting 030.Border_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 65 images processed
# Starting 007.American_foxhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 025.Black_and_tan_coonhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 46 images processed
# Starting 004.Akita images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 117.Pekingese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 132.Xoloitzcuintli images
# 10 images processed
# 20 images processed
# 30 images processed
# 33 images processed
# Starting 096.Labrador_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 54 images processed
# Starting 035.Boykin_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 093.Kerry_blue_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 002.Afghan_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 73 images processed
# Starting 114.Otterhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 44 images processed
# Starting 027.Bloodhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 046.Cavalier_king_charles_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 84 images processed
# Starting 033.Bouvier_des_flandres images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 56 images processed
# Starting 038.Brussels_griffon images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 71 images processed
# Starting 031.Borzoi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# Starting 122.Pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# Starting 014.Basenji images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 86 images processed
# Starting 047.Chesapeake_bay_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 67 images processed
# Starting 006.American_eskimo_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 050.Chinese_shar-pei images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 005.Alaskan_malamute images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 96 images processed
# Starting 062.English_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 083.Ibizan_hound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 101.Maltese images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 084.Icelandic_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 123.Pomeranian images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 061.English_cocker_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 76 images processed
# Starting 058.Dandie_dinmont_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 044.Cane_corso images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# Starting 059.Doberman_pinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 113.Old_english_sheepdog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 49 images processed
# Starting 022.Belgian_tervuren images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 070.German_pinscher images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 118.Pembroke_welsh_corgi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 097.Lakeland_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 080.Greater_swiss_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 57 images processed
# Starting 077.Gordon_setter images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 54 images processed
# Starting 013.Australian_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 009.American_water_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 075.Glen_of_imaal_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 55 images processed
# Starting 119.Petit_basset_griffon_vendeen images
# 10 images processed
# 20 images processed
# 30 images processed
# 39 images processed
# Starting 057.Dalmatian images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 89 images processed
# Starting 043.Canaan_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 017.Bearded_collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 77 images processed
# Starting 053.Cocker_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 59 images processed
# Starting 068.Flat-coated_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 129.Tibetan_mastiff images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 010.Anatolian_shepherd_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 012.Australian_shepherd images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 83 images processed
# Starting 019.Bedlington_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 128.Smooth_fox_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 131.Wirehaired_pointing_griffon images
# 10 images processed
# 20 images processed
# 30 images processed
# 37 images processed
# Starting 110.Norwegian_lundehund images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 41 images processed
# Starting 104.Miniature_schnauzer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 011.Australian_cattle_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 83 images processed
# Starting 087.Irish_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 82 images processed
# Starting 029.Border_collie images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 90 images processed
# 93 images processed
# Starting 051.Chow_chow images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 115.Papillon images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 79 images processed
# Starting 018.Beauceron images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 020.Belgian_malinois images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 063.English_springer_spaniel images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 036.Briard images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed
# Starting 098.Leonberger images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 57 images processed
# Starting .ipynb_checkpoints images
# Starting 072.German_shorthaired_pointer images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# Starting 106.Newfoundland images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 62 images processed
# Starting 049.Chinese_crested images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 63 images processed
# Starting 079.Great_pyrenees images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 74 images processed
# Starting 116.Parson_russell_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 38 images processed
# Starting 090.Italian_greyhound images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 73 images processed
# Starting 107.Norfolk_terrier images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 58 images processed
# Starting 099.Lhasa_apso images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 53 images processed
# Starting 045.Cardigan_welsh_corgi images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 66 images processed
# Starting 112.Nova_scotia_duck_tolling_retriever images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 67 images processed
# Starting 067.Finnish_spitz images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 071.German_shepherd_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 78 images processed
# Starting 125.Portuguese_water_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 42 images processed
# Starting 023.Bernese_mountain_dog images
# 10 images processed
# 20 images processed
# 30 images processed
# 40 images processed
# 50 images processed
# 60 images processed
# 70 images processed
# 80 images processed
# 81 images processed

# %%
# write codes to file
with open('codes', 'w') as f:
    codes.tofile(f)
    
# write labels to file
import csv
with open('labels', 'w') as f:
    writer = csv.writer(f, delimiter='\n')
    writer.writerow(labels)

# %%
# read codes and labels from file
import csv

with open('labels') as f:
    reader = csv.reader(f, delimiter='\n')
    labels = np.array([each for each in reader]).squeeze()
with open('codes') as f:
    codes = np.fromfile(f, dtype=np.float32)
    codes = codes.reshape((len(labels), -1))

# %%
# One-hot encode labels
from sklearn import preprocessing

lb = preprocessing.LabelBinarizer()
lb.fit(labels)
labels_vecs = lb.transform(labels)

# %%
import sklearn
from sklearn import svm
from sklearn import cross_validation, grid_search
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.svm import SVC
from sklearn.externals import joblib
 
def train_svm_classifer(codes, labels):
    # save 20% of data for performance evaluation
    X_train, X_test, y_train, y_test = cross_validation.train_test_split(codes, labels, train_size=0.8, test_size=0.1)
    print("Train shapes (x, y):", X_train.shape, y_train.shape)
    print("Test shapes (x, y):", X_test.shape, y_test.shape)
    
    clf = svm.SVC(C=1, kernel='rbf', probability=True)
    clf.fit(X_train, y_train)
        
    score = clf.score(X_test,y_test)
    print("Test accuracy:", score)
    
    y_predict=clf.predict(X_test)
    return y_predict

# %%
train_svm_classifer(codes,labels)
# Out:
# Train shapes (x, y): (6623, 4096) (6623,)
# Test shapes (x, y): (828, 4096) (828,)
# Test accuracy: 0.863526570048
# array(['017.Bearded_collie', '002.Afghan_hound', '015.Basset_hound',
#        '056.Dachshund', '045.Cardigan_welsh_corgi', '029.Border_collie',
#        '044.Cane_corso', '115.Papillon', '131.Wirehaired_pointing_griffon',
#        '038.Brussels_griffon', '015.Basset_hound',
#        '113.Old_english_sheepdog', '058.Dandie_dinmont_terrier',
#        '119.Petit_basset_griffon_vendeen', '050.Chinese_shar-pei',
#        '034.Boxer', '026.Black_russian_terrier', '002.Afghan_hound',
#        '024.Bichon_frise', '051.Chow_chow', '037.Brittany',
#        '107.Norfolk_terrier', '063.English_springer_spaniel',
#        '015.Basset_hound', '111.Norwich_terrier', '020.Belgian_malinois',
#        '088.Irish_water_spaniel', '021.Belgian_sheepdog', '082.Havanese',
#        '002.Afghan_hound', '014.Basenji', '010.Anatolian_shepherd_dog',
#        '063.English_springer_spaniel', '115.Papillon',
#        '049.Chinese_crested', '076.Golden_retriever',
#        '068.Flat-coated_retriever', '084.Icelandic_sheepdog', '054.Collie',
#        '044.Cane_corso', '017.Bearded_collie', '018.Beauceron',
#        '001.Affenpinscher', '020.Belgian_malinois',
#        '013.Australian_terrier', '125.Portuguese_water_dog',
#        '090.Italian_greyhound', '075.Glen_of_imaal_terrier',
#        '012.Australian_shepherd', '087.Irish_terrier',
#        '030.Border_terrier', '081.Greyhound', '022.Belgian_tervuren',
#        '042.Cairn_terrier', '097.Lakeland_terrier',
#        '068.Flat-coated_retriever', '007.American_foxhound',
#        '089.Irish_wolfhound', '091.Japanese_chin', '090.Italian_greyhound',
#        '055.Curly-coated_retriever', '021.Belgian_sheepdog',
#        '105.Neapolitan_mastiff', '082.Havanese', '087.Irish_terrier',
#        '005.Alaskan_malamute', '014.Basenji',
#        '073.German_wirehaired_pointer', '044.Cane_corso', '114.Otterhound',
#        '052.Clumber_spaniel', '029.Border_collie', '053.Cocker_spaniel',
#        '075.Glen_of_imaal_terrier', '034.Boxer', '120.Pharaoh_hound',
#        '088.Irish_water_spaniel', '041.Bullmastiff',
#        '025.Black_and_tan_coonhound', '132.Xoloitzcuintli',
#        '015.Basset_hound', '080.Greater_swiss_mountain_dog',
#        '104.Miniature_schnauzer', '121.Plott', '084.Icelandic_sheepdog',
#        '029.Border_collie', '039.Bull_terrier', '091.Japanese_chin',
#        '063.English_springer_spaniel', '132.Xoloitzcuintli',
#        '039.Bull_terrier', '044.Cane_corso', '115.Papillon',
#        '073.German_wirehaired_pointer', '116.Parson_russell_terrier',
#        '129.Tibetan_mastiff', '029.Border_collie',
#        '116.Parson_russell_terrier', '023.Bernese_mountain_dog',
#        '096.Labrador_retriever', '038.Brussels_griffon',
#        '105.Neapolitan_mastiff', '041.Bullmastiff', '041.Bullmastiff',
#        '079.Great_pyrenees', '014.Basenji', '047.Chesapeake_bay_retriever',
#        '063.English_springer_spaniel', '017.Bearded_collie', '004.Akita',
#        '051.Chow_chow', '025.Black_and_tan_coonhound',
#        '059.Doberman_pinscher', '043.Canaan_dog', '056.Dachshund',
#        '125.Portuguese_water_dog', '005.Alaskan_malamute', '095.Kuvasz',
#        '078.Great_dane', '076.Golden_retriever',
#        '085.Irish_red_and_white_setter', '040.Bulldog', '015.Basset_hound',
#        '018.Beauceron', '118.Pembroke_welsh_corgi',
#        '073.German_wirehaired_pointer', '023.Bernese_mountain_dog',
#        '049.Chinese_crested', '032.Boston_terrier',
#        '133.Yorkshire_terrier', '014.Basenji', '082.Havanese',
#        '123.Pomeranian', '003.Airedale_terrier',
#        '068.Flat-coated_retriever', '040.Bulldog',
#        '012.Australian_shepherd', '002.Afghan_hound',
#        '010.Anatolian_shepherd_dog', '082.Havanese', '117.Pekingese',
#        '099.Lhasa_apso', '070.German_pinscher',
#        '112.Nova_scotia_duck_tolling_retriever', '081.Greyhound',
#        '034.Boxer', '033.Bouvier_des_flandres',
#        '080.Greater_swiss_mountain_dog', '030.Border_terrier',
#        '028.Bluetick_coonhound', '069.French_bulldog', '114.Otterhound',
#        '017.Bearded_collie', '013.Australian_terrier',
#        '058.Dandie_dinmont_terrier', '077.Gordon_setter', '114.Otterhound',
#        '067.Finnish_spitz', '033.Bouvier_des_flandres', '106.Newfoundland',
#        '056.Dachshund', '022.Belgian_tervuren', '124.Poodle',
#        '060.Dogue_de_bordeaux', '056.Dachshund', '083.Ibizan_hound',
#        '041.Bullmastiff', '047.Chesapeake_bay_retriever', '122.Pointer',
#        '064.English_toy_spaniel', '004.Akita',
#        '063.English_springer_spaniel', '105.Neapolitan_mastiff',
#        '085.Irish_red_and_white_setter', '044.Cane_corso',
#        '006.American_eskimo_dog', '091.Japanese_chin',
#        '112.Nova_scotia_duck_tolling_retriever',
#        '061.English_cocker_spaniel', '049.Chinese_crested',
#        '118.Pembroke_welsh_corgi',
#        '112.Nova_scotia_duck_tolling_retriever', '099.Lhasa_apso',
#        '034.Boxer', '078.Great_dane', '085.Irish_red_and_white_setter',
#        '036.Briard', '118.Pembroke_welsh_corgi', '036.Briard',
#        '089.Irish_wolfhound', '123.Pomeranian', '014.Basenji',
#        '054.Collie', '046.Cavalier_king_charles_spaniel',
#        '058.Dandie_dinmont_terrier', '008.American_staffordshire_terrier',
#        '128.Smooth_fox_terrier', '122.Pointer', '038.Brussels_griffon',
#        '090.Italian_greyhound', '016.Beagle', '083.Ibizan_hound',
#        '089.Irish_wolfhound', '084.Icelandic_sheepdog',
#        '050.Chinese_shar-pei', '050.Chinese_shar-pei',
#        '008.American_staffordshire_terrier', '070.German_pinscher',
#        '093.Kerry_blue_terrier', '014.Basenji', '074.Giant_schnauzer',
#        '044.Cane_corso', '041.Bullmastiff', '015.Basset_hound',
#        '082.Havanese', '117.Pekingese', '055.Curly-coated_retriever',
#        '015.Basset_hound', '071.German_shepherd_dog', '117.Pekingese',
#        '003.Airedale_terrier', '069.French_bulldog', '098.Leonberger',
#        '080.Greater_swiss_mountain_dog', '013.Australian_terrier',
#        '036.Briard', '024.Bichon_frise', '132.Xoloitzcuintli',
#        '017.Bearded_collie', '014.Basenji', '059.Doberman_pinscher',
#        '036.Briard', '119.Petit_basset_griffon_vendeen', '018.Beauceron',
#        '035.Boykin_spaniel', '036.Briard', '049.Chinese_crested',
#        '071.German_shepherd_dog', '067.Finnish_spitz', '002.Afghan_hound',
#        '069.French_bulldog', '050.Chinese_shar-pei',
#        '059.Doberman_pinscher', '049.Chinese_crested',
#        '061.English_cocker_spaniel', '079.Great_pyrenees',
#        '071.German_shepherd_dog', '001.Affenpinscher',
#        '047.Chesapeake_bay_retriever', '016.Beagle', '107.Norfolk_terrier',
#        '080.Greater_swiss_mountain_dog', '029.Border_collie', '034.Boxer',
#        '001.Affenpinscher', '046.Cavalier_king_charles_spaniel',
#        '110.Norwegian_lundehund', '123.Pomeranian',
#        '009.American_water_spaniel', '028.Bluetick_coonhound',
#        '033.Bouvier_des_flandres', '120.Pharaoh_hound', '014.Basenji',
#        '011.Australian_cattle_dog', '133.Yorkshire_terrier',
#        '029.Border_collie', '027.Bloodhound', '108.Norwegian_buhund',
#        '042.Cairn_terrier', '088.Irish_water_spaniel',
#        '046.Cavalier_king_charles_spaniel', '018.Beauceron',
#        '048.Chihuahua', '130.Welsh_springer_spaniel',
#        '060.Dogue_de_bordeaux', '071.German_shepherd_dog',
#        '073.German_wirehaired_pointer', '075.Glen_of_imaal_terrier',
#        '056.Dachshund', '063.English_springer_spaniel',
#        '079.Great_pyrenees', '055.Curly-coated_retriever',
#        '114.Otterhound', '071.German_shepherd_dog',
#        '080.Greater_swiss_mountain_dog', '128.Smooth_fox_terrier',
#        '080.Greater_swiss_mountain_dog', '075.Glen_of_imaal_terrier',
#        '060.Dogue_de_bordeaux', '074.Giant_schnauzer', '127.Silky_terrier',
#        '015.Basset_hound', '016.Beagle', '115.Papillon', '094.Komondor',
#        '113.Old_english_sheepdog', '104.Miniature_schnauzer',
#        '018.Beauceron', '029.Border_collie', '024.Bichon_frise',
#        '070.German_pinscher', '041.Bullmastiff',
#        '011.Australian_cattle_dog', '005.Alaskan_malamute',
#        '024.Bichon_frise', '062.English_setter', '042.Cairn_terrier',
#        '023.Bernese_mountain_dog', '076.Golden_retriever',
#        '003.Airedale_terrier', '051.Chow_chow', '037.Brittany',
#        '044.Cane_corso', '076.Golden_retriever', '051.Chow_chow',
#        '104.Miniature_schnauzer', '045.Cardigan_welsh_corgi',
#        '002.Afghan_hound', '009.American_water_spaniel',
#        '085.Irish_red_and_white_setter', '017.Bearded_collie',
#        '082.Havanese', '042.Cairn_terrier',
#        '112.Nova_scotia_duck_tolling_retriever', '070.German_pinscher',
#        '031.Borzoi', '127.Silky_terrier', '038.Brussels_griffon',
#        '079.Great_pyrenees', '116.Parson_russell_terrier',
#        '046.Cavalier_king_charles_spaniel', '099.Lhasa_apso',
#        '042.Cairn_terrier', '018.Beauceron', '071.German_shepherd_dog',
#        '094.Komondor', '112.Nova_scotia_duck_tolling_retriever',
#        '016.Beagle', '083.Ibizan_hound', '111.Norwich_terrier',
#        '048.Chihuahua', '039.Bull_terrier', '077.Gordon_setter',
#        '120.Pharaoh_hound', '086.Irish_setter', '105.Neapolitan_mastiff',
#        '042.Cairn_terrier', '042.Cairn_terrier', '002.Afghan_hound',
#        '125.Portuguese_water_dog', '068.Flat-coated_retriever',
#        '059.Doberman_pinscher', '035.Boykin_spaniel',
#        '060.Dogue_de_bordeaux', '112.Nova_scotia_duck_tolling_retriever',
#        '104.Miniature_schnauzer', '008.American_staffordshire_terrier',
#        '073.German_wirehaired_pointer', '126.Saint_bernard',
#        '093.Kerry_blue_terrier', '084.Icelandic_sheepdog', '057.Dalmatian',
#        '057.Dalmatian', '005.Alaskan_malamute', '040.Bulldog',
#        '132.Xoloitzcuintli', '120.Pharaoh_hound', '028.Bluetick_coonhound',
#        '046.Cavalier_king_charles_spaniel', '114.Otterhound',
#        '070.German_pinscher', '095.Kuvasz', '003.Airedale_terrier',
#        '046.Cavalier_king_charles_spaniel', '037.Brittany',
#        '081.Greyhound', '114.Otterhound', '034.Boxer',
#        '050.Chinese_shar-pei', '008.American_staffordshire_terrier',
#        '011.Australian_cattle_dog', '026.Black_russian_terrier',
#        '059.Doberman_pinscher', '063.English_springer_spaniel',
#        '079.Great_pyrenees', '053.Cocker_spaniel',
#        '033.Bouvier_des_flandres', '006.American_eskimo_dog',
#        '061.English_cocker_spaniel', '030.Border_terrier',
#        '061.English_cocker_spaniel', '092.Keeshond',
#        '005.Alaskan_malamute', '002.Afghan_hound', '040.Bulldog',
#        '042.Cairn_terrier', '129.Tibetan_mastiff', '115.Papillon',
#        '015.Basset_hound', '079.Great_pyrenees',
#        '118.Pembroke_welsh_corgi', '066.Field_spaniel', '115.Papillon',
#        '130.Welsh_springer_spaniel', '025.Black_and_tan_coonhound',
#        '034.Boxer', '073.German_wirehaired_pointer', '081.Greyhound',
#        '069.French_bulldog', '081.Greyhound', '019.Bedlington_terrier',
#        '072.German_shorthaired_pointer', '098.Leonberger',
#        '003.Airedale_terrier', '043.Canaan_dog', '101.Maltese',
#        '041.Bullmastiff', '005.Alaskan_malamute', '024.Bichon_frise',
#        '004.Akita', '126.Saint_bernard', '129.Tibetan_mastiff',
#        '019.Bedlington_terrier', '057.Dalmatian', '128.Smooth_fox_terrier',
#        '036.Briard', '038.Brussels_griffon', '078.Great_dane',
#        '013.Australian_terrier', '118.Pembroke_welsh_corgi',
#        '129.Tibetan_mastiff', '014.Basenji', '024.Bichon_frise',
#        '009.American_water_spaniel', '023.Bernese_mountain_dog',
#        '047.Chesapeake_bay_retriever', '117.Pekingese',
#        '068.Flat-coated_retriever', '011.Australian_cattle_dog',
#        '078.Great_dane', '130.Welsh_springer_spaniel', '127.Silky_terrier',
#        '044.Cane_corso', '079.Great_pyrenees', '132.Xoloitzcuintli',
#        '036.Briard', '104.Miniature_schnauzer',
#        '080.Greater_swiss_mountain_dog', '030.Border_terrier',
#        '089.Irish_wolfhound', '060.Dogue_de_bordeaux', '051.Chow_chow',
#        '133.Yorkshire_terrier', '099.Lhasa_apso', '122.Pointer',
#        '065.Entlebucher_mountain_dog', '035.Boykin_spaniel',
#        '046.Cavalier_king_charles_spaniel', '034.Boxer', '082.Havanese',
#        '128.Smooth_fox_terrier', '004.Akita', '014.Basenji',
#        '015.Basset_hound', '113.Old_english_sheepdog',
#        '079.Great_pyrenees', '080.Greater_swiss_mountain_dog',
#        '071.German_shepherd_dog', '075.Glen_of_imaal_terrier',
#        '052.Clumber_spaniel', '055.Curly-coated_retriever',
#        '083.Ibizan_hound', '094.Komondor', '101.Maltese', '044.Cane_corso',
#        '078.Great_dane', '079.Great_pyrenees', '087.Irish_terrier',
#        '012.Australian_shepherd', '068.Flat-coated_retriever',
#        '051.Chow_chow', '032.Boston_terrier', '120.Pharaoh_hound',
#        '095.Kuvasz', '074.Giant_schnauzer', '060.Dogue_de_bordeaux',
#        '015.Basset_hound', '087.Irish_terrier', '015.Basset_hound',
#        '060.Dogue_de_bordeaux', '087.Irish_terrier', '057.Dalmatian',
#        '044.Cane_corso', '015.Basset_hound', '004.Akita',
#        '015.Basset_hound', '050.Chinese_shar-pei', '029.Border_collie',
#        '020.Belgian_malinois', '075.Glen_of_imaal_terrier',
#        '023.Bernese_mountain_dog', '029.Border_collie',
#        '060.Dogue_de_bordeaux', '076.Golden_retriever',
#        '019.Bedlington_terrier', '074.Giant_schnauzer',
#        '068.Flat-coated_retriever', '121.Plott', '093.Kerry_blue_terrier',
#        '010.Anatolian_shepherd_dog', '045.Cardigan_welsh_corgi',
#        '031.Borzoi', '010.Anatolian_shepherd_dog', '120.Pharaoh_hound',
#        '088.Irish_water_spaniel', '002.Afghan_hound', '121.Plott',
#        '075.Glen_of_imaal_terrier', '075.Glen_of_imaal_terrier',
#        '011.Australian_cattle_dog', '014.Basenji',
#        '055.Curly-coated_retriever', '082.Havanese', '002.Afghan_hound',
#        '011.Australian_cattle_dog', '069.French_bulldog', '031.Borzoi',
#        '055.Curly-coated_retriever', '115.Papillon', '094.Komondor',
#        '070.German_pinscher', '036.Briard', '096.Labrador_retriever',
#        '026.Black_russian_terrier', '010.Anatolian_shepherd_dog',
#        '020.Belgian_malinois', '015.Basset_hound', '124.Poodle',
#        '120.Pharaoh_hound', '083.Ibizan_hound', '087.Irish_terrier',
#        '063.English_springer_spaniel', '104.Miniature_schnauzer',
#        '006.American_eskimo_dog', '029.Border_collie',
#        '047.Chesapeake_bay_retriever', '098.Leonberger',
#        '006.American_eskimo_dog', '033.Bouvier_des_flandres',
#        '091.Japanese_chin', '037.Brittany', '090.Italian_greyhound',
#        '128.Smooth_fox_terrier', '013.Australian_terrier',
#        '011.Australian_cattle_dog', '015.Basset_hound',
#        '068.Flat-coated_retriever', '118.Pembroke_welsh_corgi',
#        '043.Canaan_dog', '122.Pointer', '129.Tibetan_mastiff',
#        '023.Bernese_mountain_dog', '006.American_eskimo_dog',
#        '019.Bedlington_terrier', '104.Miniature_schnauzer',
#        '050.Chinese_shar-pei', '020.Belgian_malinois',
#        '021.Belgian_sheepdog', '021.Belgian_sheepdog', '034.Boxer',
#        '055.Curly-coated_retriever', '008.American_staffordshire_terrier',
#        '122.Pointer', '016.Beagle', '031.Borzoi', '051.Chow_chow',
#        '070.German_pinscher', '110.Norwegian_lundehund',
#        '021.Belgian_sheepdog', '065.Entlebucher_mountain_dog',
#        '003.Airedale_terrier', '082.Havanese', '017.Bearded_collie',
#        '015.Basset_hound', '095.Kuvasz', '071.German_shepherd_dog',
#        '101.Maltese', '097.Lakeland_terrier', '023.Bernese_mountain_dog',
#        '112.Nova_scotia_duck_tolling_retriever', '029.Border_collie',
#        '008.American_staffordshire_terrier',
#        '046.Cavalier_king_charles_spaniel', '012.Australian_shepherd',
#        '129.Tibetan_mastiff', '056.Dachshund', '003.Airedale_terrier',
#        '097.Lakeland_terrier', '051.Chow_chow', '002.Afghan_hound',
#        '037.Brittany', '059.Doberman_pinscher', '114.Otterhound',
#        '106.Newfoundland', '055.Curly-coated_retriever',
#        '039.Bull_terrier', '020.Belgian_malinois',
#        '131.Wirehaired_pointing_griffon', '020.Belgian_malinois',
#        '016.Beagle', '076.Golden_retriever',
#        '085.Irish_red_and_white_setter', '058.Dandie_dinmont_terrier',
#        '065.Entlebucher_mountain_dog', '063.English_springer_spaniel',
#        '070.German_pinscher', '054.Collie', '076.Golden_retriever',
#        '060.Dogue_de_bordeaux', '065.Entlebucher_mountain_dog',
#        '082.Havanese', '061.English_cocker_spaniel', '120.Pharaoh_hound',
#        '081.Greyhound', '074.Giant_schnauzer',
#        '085.Irish_red_and_white_setter', '131.Wirehaired_pointing_griffon',
#        '017.Bearded_collie', '111.Norwich_terrier', '048.Chihuahua',
#        '123.Pomeranian', '023.Bernese_mountain_dog', '111.Norwich_terrier',
#        '039.Bull_terrier', '024.Bichon_frise',
#        '008.American_staffordshire_terrier', '041.Bullmastiff',
#        '011.Australian_cattle_dog', '101.Maltese',
#        '010.Anatolian_shepherd_dog', '027.Bloodhound',
#        '046.Cavalier_king_charles_spaniel', '109.Norwegian_elkhound',
#        '117.Pekingese', '113.Old_english_sheepdog', '092.Keeshond',
#        '091.Japanese_chin', '106.Newfoundland', '060.Dogue_de_bordeaux',
#        '085.Irish_red_and_white_setter', '066.Field_spaniel',
#        '014.Basenji', '065.Entlebucher_mountain_dog',
#        '076.Golden_retriever', '118.Pembroke_welsh_corgi', '051.Chow_chow',
#        '129.Tibetan_mastiff', '053.Cocker_spaniel',
#        '133.Yorkshire_terrier', '109.Norwegian_elkhound',
#        '021.Belgian_sheepdog', '012.Australian_shepherd', '036.Briard',
#        '047.Chesapeake_bay_retriever', '088.Irish_water_spaniel',
#        '068.Flat-coated_retriever', '034.Boxer', '002.Afghan_hound',
#        '049.Chinese_crested', '003.Airedale_terrier',
#        '090.Italian_greyhound', '084.Icelandic_sheepdog',
#        '127.Silky_terrier', '057.Dalmatian', '003.Airedale_terrier',
#        '009.American_water_spaniel', '096.Labrador_retriever',
#        '101.Maltese', '010.Anatolian_shepherd_dog',
#        '063.English_springer_spaniel', '056.Dachshund',
#        '023.Bernese_mountain_dog', '076.Golden_retriever',
#        '113.Old_english_sheepdog', '116.Parson_russell_terrier',
#        '028.Bluetick_coonhound', '101.Maltese', '128.Smooth_fox_terrier',
#        '035.Boykin_spaniel', '045.Cardigan_welsh_corgi', '124.Poodle',
#        '120.Pharaoh_hound', '082.Havanese', '032.Boston_terrier',
#        '001.Affenpinscher', '016.Beagle', '107.Norfolk_terrier',
#        '044.Cane_corso', '082.Havanese', '087.Irish_terrier',
#        '050.Chinese_shar-pei', '001.Affenpinscher', '098.Leonberger',
#        '112.Nova_scotia_duck_tolling_retriever', '034.Boxer',
#        '057.Dalmatian', '012.Australian_shepherd',
#        '084.Icelandic_sheepdog', '051.Chow_chow', '013.Australian_terrier',
#        '004.Akita', '051.Chow_chow', '001.Affenpinscher',
#        '059.Doberman_pinscher', '049.Chinese_crested', '004.Akita',
#        '049.Chinese_crested', '011.Australian_cattle_dog',
#        '091.Japanese_chin', '060.Dogue_de_bordeaux', '123.Pomeranian',
#        '030.Border_terrier', '061.English_cocker_spaniel',
#        '041.Bullmastiff', '120.Pharaoh_hound', '028.Bluetick_coonhound',
#        '118.Pembroke_welsh_corgi', '057.Dalmatian', '014.Basenji',
#        '022.Belgian_tervuren', '106.Newfoundland', '060.Dogue_de_bordeaux',
#        '032.Boston_terrier', '057.Dalmatian', '032.Boston_terrier',
#        '058.Dandie_dinmont_terrier', '089.Irish_wolfhound',
#        '048.Chihuahua', '002.Afghan_hound', '019.Bedlington_terrier',
#        '077.Gordon_setter', '101.Maltese', '118.Pembroke_welsh_corgi',
#        '115.Papillon', '023.Bernese_mountain_dog',
#        '055.Curly-coated_retriever', '029.Border_collie', '027.Bloodhound',
#        '031.Borzoi', '081.Greyhound', '027.Bloodhound', '092.Keeshond',
#        '070.German_pinscher', '065.Entlebucher_mountain_dog', '095.Kuvasz',
#        '004.Akita', '012.Australian_shepherd', '016.Beagle',
#        '020.Belgian_malinois', '069.French_bulldog',
#        '090.Italian_greyhound', '036.Briard', '071.German_shepherd_dog',
#        '036.Briard', '005.Alaskan_malamute', '018.Beauceron',
#        '042.Cairn_terrier', '021.Belgian_sheepdog', '024.Bichon_frise',
#        '013.Australian_terrier', '006.American_eskimo_dog', '054.Collie',
#        '021.Belgian_sheepdog', '079.Great_pyrenees', '081.Greyhound',
#        '127.Silky_terrier', '033.Bouvier_des_flandres',
#        '087.Irish_terrier', '077.Gordon_setter', '018.Beauceron',
#        '031.Borzoi', '076.Golden_retriever', '034.Boxer',
#        '076.Golden_retriever', '105.Neapolitan_mastiff', '094.Komondor',
#        '114.Otterhound', '048.Chihuahua', '089.Irish_wolfhound',
#        '010.Anatolian_shepherd_dog', '053.Cocker_spaniel',
#        '084.Icelandic_sheepdog', '081.Greyhound', '017.Bearded_collie',
#        '029.Border_collie', '114.Otterhound', '051.Chow_chow',
#        '028.Bluetick_coonhound', '089.Irish_wolfhound',
#        '049.Chinese_crested', '083.Ibizan_hound',
#        '072.German_shorthaired_pointer', '070.German_pinscher',
#        '085.Irish_red_and_white_setter', '040.Bulldog',
#        '063.English_springer_spaniel', '083.Ibizan_hound',
#        '006.American_eskimo_dog', '007.American_foxhound',
#        '021.Belgian_sheepdog', '057.Dalmatian', '034.Boxer',
#        '061.English_cocker_spaniel', '107.Norfolk_terrier',
#        '108.Norwegian_buhund', '033.Bouvier_des_flandres',
#        '093.Kerry_blue_terrier', '036.Briard', '036.Briard',
#        '044.Cane_corso', '040.Bulldog', '037.Brittany', '114.Otterhound',
#        '101.Maltese', '024.Bichon_frise', '124.Poodle',
#        '076.Golden_retriever', '072.German_shorthaired_pointer'],
#       dtype='<U38')
